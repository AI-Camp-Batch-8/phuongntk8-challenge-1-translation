# %% [markdown]
# This notebook builds an NMT model with OpenNMT by following this [tutorial](https://opennmt.net/OpenNMT-py/quickstart.html).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 216 kB 19.9 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 58.9 MB/s
# ...
#      |████████████████████████████████| 57 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 73 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.5 MB/s
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !pip show OpenNMT-py
# Out:
# Name: OpenNMT-py
# Version: 2.2.0
# Summary: A python implementation of OpenNMT
# Home-page: UNKNOWN
# Author: None
# Author-email: None
# License: UNKNOWN
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: tensorboard, configargparse, pyonmttok, torch, torchtext, waitress, flask, pyyaml
# Required-by:

# %%
# !onmt_build_vocab -config /content/drive/MyDrive/qai_hackathon_nmt/config/menu_vi_en.yaml -n_sample 12168
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# Corpus test's weight should be given. We default it to 1 for you.
# [2022-08-14 10:37:55,166 INFO] Counter vocab from 12168 samples.
# [2022-08-14 10:37:55,166 INFO] Build vocab on 12168 transformed examples/corpus.
# [2022-08-14 10:37:55,174 INFO] corpus_1's transforms: TransformPipe()
# [2022-08-14 10:37:55,174 INFO] test's transforms: TransformPipe()
# [2022-08-14 10:37:55,198 WARNING] Empty line exists in corpus_1#2465.
# [2022-08-14 10:37:55,375 INFO] Counters src:2861
# [2022-08-14 10:37:55,375 INFO] Counters tgt:3383

# %%
# Need to have runtime type = GPU before running this code cell

# !onmt_train -config /content/drive/MyDrive/qai_hackathon_nmt/config/menu_vi_en.yaml
# Out:
# [2022-08-14 10:38:09,801 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-08-14 10:38:09,802 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-08-14 10:38:09,802 INFO] Missing transforms field for valid data, set to default: [].
# [2022-08-14 10:38:09,803 INFO] Missing transforms field for test data, set to default: [].
# [2022-08-14 10:38:09,803 WARNING] Corpus test's weight should be given. We default it to 1 for you.
# [2022-08-14 10:38:09,803 INFO] Parsed 3 corpora from -data.
# [2022-08-14 10:38:09,804 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-08-14 10:38:09,804 INFO] Loading vocab from text file...
# [2022-08-14 10:38:09,804 INFO] Loading src vocabulary from /content/drive/MyDrive/qai_hackathon_nmt/run/menu.vocab.src
# [2022-08-14 10:38:09,811 INFO] Loaded src vocab has 2861 tokens.
# ...

# %%
# !onmt_translate -model /content/drive/MyDrive/qai_hackathon_nmt/run/model_step_1000.pt -src /content/drive/MyDrive/qai_hackathon_nmt/data/src-test.txt -output /content/drive/MyDrive/qai_hackathon_nmt/run/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 522: ['CHÙM', 'RUỘT', 'MUỐI', 'ỚT', 'ME', 'XÍ', 'MUỘI']
# PRED 522: SALTED SALT WITH SALT
# PRED SCORE: -7.9519
#
# [2022-08-14 10:43:59,891 INFO]
# SENT 523: ['COMBO', '2', 'NGƯỜI']
# PRED 523: COMBO COMBO
# PRED SCORE: -1.9783
#
# [2022-08-14 10:43:59,891 INFO]
# SENT 524: ['CAM', 'VẮT']
# PRED 524: ORANGE JUICE
# PRED SCORE: -0.0528
#
# [2022-08-14 10:43:59,891 INFO]
# SENT 525: ['SỮA', 'CHUA', 'ĐÀO']
# PRED 525: PEACH YOGURT
# PRED SCORE: -0.0925
#
# [2022-08-14 10:43:59,892 INFO]
# SENT 526: ['ẾCH', 'XÔI']
# PRED 526: FROG
# PRED SCORE: -1.4045
#
# [2022-08-14 10:43:59,892 INFO]
# SENT 527: ['BÁNH', 'TRÁNG', 'TRỘN']
# PRED 527: MIXED PAPER
# PRED SCORE: -1.0839
#
# [2022-08-14 10:43:59,892 INFO]
# SENT 528: ['HƯƠNG', 'VỊ', 'TẾT']
# PRED 528: RASPBERRY
# PRED SCORE: -6.4682
#
# [2022-08-14 10:43:59,892 INFO]
# SENT 529: ['TRÀ', 'ĐÀO', 'CAM', 'SẢ', 'M']
# PRED 529: ORANGE ORANGE TEA
# PRED SCORE: -1.3195
#
# ...
